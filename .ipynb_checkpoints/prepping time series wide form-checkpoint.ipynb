# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os
# set random seed
SEED = 321
np.random.seed(SEED)

# %%
plt.rcParams['figure.facecolor']='white'
plt.rcParams['figure.figsize']=(12,4)
#import tick customization tools
import matplotlib.ticker as mticks
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter
sns.set_context("talk", font_scale=0.9)

# %%
def format_xdates(ax, fig=None, xtick_fontweight='bold',
               title= None):
    """Formats x-axis with minor ticks every 3 months, and major 
    ticks every year. Includes different grid options for visibility"""
    # create the locator to place ticks every 3 months.
    loc_3months = mdates.MonthLocator(interval=3)
    fmt_months = mdates.DateFormatter("%b")
    ## for major year ticks
    loc_year = mdates.YearLocator()
    fmt_year = mdates.DateFormatter("%Y")
    
    ## Change the font of the major ticks to stand out
    ax.set_xticks(ax.get_xticks())
    ax.set_xticklabels(ax.get_xticklabels(), 
                       fontweight=xtick_fontweight) 
    ax.set_xticklabel_format(style = 'plain')
    
    ## customize minor ticks
    ax.xaxis.set_minor_locator(loc_3months)
    ax.xaxis.set_minor_formatter(fmt_months)
    ## customize major ticks
    ax.xaxis.set_major_locator(loc_year)
    ax.xaxis.set_major_formatter(fmt_year)
    ## Making major/minor gridlines visually distince
    ax.grid(which='minor',axis='x',ls=":")
    ax.grid(which='major',axis='x',color='k')
    if fig is None:
        fig = ax.get_figure()
    ## rotate the dates
    fig.autofmt_xdate(which='major',rotation=90,ha='center')
    return fig,ax

# %%
data="C:/Users/dell/Downloads/City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month - City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"
home_df = pd.read_csv(data)
home_df.info()
home_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22467 entries, 0 to 22466
# Columns: 281 entries, RegionID to 2022-09-30
# dtypes: float64(273), int64(2), object(6)
# memory usage: 48.2+ MB
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# 1    234401.0  ...    924019.0    928991.0    937936.0    953874.0
# ...

# %%
home_df.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'CountyName', '2000-01-31', '2000-02-29',
#        ...
#        '2021-12-31', '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#        '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31', '2022-09-30'],
#       dtype='object', length=281)

# %%
city_df = home_df.loc[(home_df['SizeRank'])[0:4]]
city_df
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# 1    234401.0  ...    924019.0    928991.0    937936.0    953874.0
# 2    109079.0  ...    245783.0    248718.0    252080.0    256435.0
# ...

# %%
home_melted = pd.melt(city_df.drop(columns= ['StateName','RegionID','SizeRank']), id_vars=['RegionName', 'RegionType','State','Metro','CountyName'],
                     value_name='HomeValue', var_name='Date')
home_melted
# Out:
#        RegionName RegionType State                                  Metro  \
# 0        New York       city    NY  New York-Newark-Jersey City, NY-NJ-PA
# 1     Los Angeles       city    CA     Los Angeles-Long Beach-Anaheim, CA
# 2         Houston       city    TX   Houston-The Woodlands-Sugar Land, TX
# 3         Chicago       city    IL     Chicago-Naperville-Elgin, IL-IN-WI
# 4        New York       city    NY  New York-Newark-Jersey City, NY-NJ-PA
# ...           ...        ...   ...                                    ...
# 1087      Chicago       city    IL     Chicago-Naperville-Elgin, IL-IN-WI
# 1088     New York       city    NY  New York-Newark-Jersey City, NY-NJ-PA
# 1089  Los Angeles       city    CA     Los Angeles-Long Beach-Anaheim, CA
# 1090      Houston       city    TX   Houston-The Woodlands-Sugar Land, TX
# 1091      Chicago       city    IL     Chicago-Naperville-Elgin, IL-IN-WI
#
#               CountyName        Date  HomeValue
# ...

# %%
home_melted['Date'] = pd.to_datetime(home_melted['Date'])
home_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionName  1092 non-null   object
#  1   RegionType  1092 non-null   object
#  2   State       1092 non-null   object
#  3   Metro       1092 non-null   object
#  4   CountyName  1092 non-null   object
#  5   Date        1092 non-null   datetime64[ns]
#  6   HomeValue   1087 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 59.8+ KB

# %%
home_melted= home_melted.set_index('Date')
home_melted
# Out:
#              RegionName RegionType State  \
# Date
# 2000-01-31     New York       city    NY
# 2000-01-31  Los Angeles       city    CA
# 2000-01-31      Houston       city    TX
# 2000-01-31      Chicago       city    IL
# 2000-02-29     New York       city    NY
# ...                 ...        ...   ...
# 2022-08-31      Chicago       city    IL
# 2022-09-30     New York       city    NY
# 2022-09-30  Los Angeles       city    CA
# 2022-09-30      Houston       city    TX
# 2022-09-30      Chicago       city    IL
#
#                                             Metro          CountyName  \
# Date
# 2000-01-31  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# 2000-01-31     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
# 2000-01-31   Houston-The Woodlands-Sugar Land, TX       Harris County
# 2000-01-31     Chicago-Naperville-Elgin, IL-IN-WI         Cook County
# 2000-02-29  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# ...

# %%
rs_df = home_melted.groupby('RegionName').resample('M').sum()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_19736\3139203493.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rs_df = home_melted.groupby('RegionName').resample('M').sum()
# C:\Users\dell\AppData\Local\Temp\ipykernel_19736\3139203493.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rs_df = home_melted.groupby('RegionName').resample('M').sum()
# ...

# %%
rs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1092 entries, ('Chicago', Timestamp('2000-01-31 00:00:00', freq='M')) to ('New York', Timestamp('2022-09-30 00:00:00', freq='M'))
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   HomeValue  1092 non-null   float64
# dtypes: float64(1)
# memory usage: 22.3+ KB

# %%
rs_df.head()
# Out:
#                        HomeValue
# RegionName Date
# Chicago    2000-01-31   166139.0
#            2000-02-29   166536.0
#            2000-03-31   167368.0
#            2000-04-30   168826.0
#            2000-05-31   170499.0

# %% [markdown]
# # part 2 plotting

# %%
rs_df.index.get_level_values(0)
# Out:
# Index(['Chicago', 'Chicago', 'Chicago', 'Chicago', 'Chicago', 'Chicago',
#        'Chicago', 'Chicago', 'Chicago', 'Chicago',
#        ...
#        'New York', 'New York', 'New York', 'New York', 'New York', 'New York',
#        'New York', 'New York', 'New York', 'New York'],
#       dtype='object', name='RegionName', length=1092)

# %%
rs_df.index.get_level_values(1)
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2021-12-31', '2022-01-31', '2022-02-28', '2022-03-31',
#                '2022-04-30', '2022-05-31', '2022-06-30', '2022-07-31',
#                '2022-08-31', '2022-09-30'],
#               dtype='datetime64[ns]', name='Date', length=1092, freq=None)

# %%
unstacked = rs_df.unstack(level=0)
unstacked
def thousands(x, pos):
    'to format money into thousands'
    formatted= x/1000
    return f'${formatted:,.0f}K' 
formatter = FuncFormatter(thousands)
ax = unstacked['HomeValue'].plot()
ax.yaxis.set_major_formatter(formatter)
ax.set_ylabel('Home Value($)')
ax.set_title('Home Values of 4 Largest cities(USA)')
ax.tick_params(axis = 'x', rotation = 90)
ax.legend();

# %%
h_exp= rs_df.loc[pd.IndexSlice[:,'2008'],:]
h_exp= h_exp.idxmax()
h_exp.sum()
# Out:
# ('Los Angeles', Timestamp('2008-01-31 00:00:00', freq='M'))

# %%
m_val = rs_df.loc[h_exp]
m_val
#la had the highest typical home value at 603029K
# Out:
#                         HomeValue
# RegionName  Date
# Los Angeles 2008-01-31   603029.0

# %%
diff= unstacked.loc['11/2008':'12/2008']
change_df = diff.diff()

# %%
change_df
# Out:
#            HomeValue
# RegionName   Chicago Houston Los Angeles New York
# Date
# 2008-11-30       NaN     NaN         NaN      NaN
# 2008-12-31   -5753.0  -964.0    -12611.0  -4458.0

# %% [markdown]
# in Chicago the house values decreased by $5753
#
# in Houston house values decreased by $964
#
# in LA house values decreased by $12611
#
# and in NYC house values decreased by $4458
